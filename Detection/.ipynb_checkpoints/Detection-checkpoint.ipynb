# %% [markdown]
# ## Dependencies

# %%
pip install tensorflow
pip install scikit-learn
pip install matplotlib
pip install Pillow
# Out:
#   Cell In[1], line 1
#     pip install tensorflow
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Build, Train and Evaluate

# %% [markdown]
# <blockquote> For Training, the model takes images of size 224x224 pixels as input. </blockquote>
# <blockquote> Note: Images must be cropped to 224x224 from the center, </blockquote>
# <blockquote># as resizing can distort the pixelation texture which is crucial for detection</blockquote>.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Define the path to your dataset
dataset_path = 'D:\Intel Unnati\Intel-Unnati-Project\Detection'  # Replace with your actual dataset path

# Load the MobileNetV2 model, pre-trained on ImageNet
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
base_model.trainable = False

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)  # Binary classification: pixelated vs non-pixelated

model = Model(inputs=base_model.input, outputs=outputs)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# Prepare data generators
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)
validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(train_generator, 
                    validation_data=validation_generator, 
                    epochs=50,  # Increase if validation performance improves
                    callbacks=[early_stopping])

# Save the model after training
model.save('pixel_detection_model.h5')

# Evaluate the model
loss, accuracy = model.evaluate(validation_generator)
print(f'Validation Accuracy: {accuracy * 100:.2f}%')

# Plot training history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\I'
# <>:11: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21492\1692561524.py:11: SyntaxWarning: invalid escape sequence '\I'
#   dataset_path = 'D:\Intel Unnati\Intel-Unnati-Project\Detection'  # Replace with your actual dataset path
# Found 12 images belonging to 3 classes.
# Found 2 images belonging to 3 classes.
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0833 - loss: 2.0370 - val_accuracy: 0.0000e+00 - val_loss: 0.9203
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.0833 - loss: 1.4243 - val_accuracy: 0.0000e+00 - val_loss: 0.3893
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.0833 - loss: 0.8555 - val_accuracy: 0.0000e+00 - val_loss: -0.1097
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: 0.3292 - val_accuracy: 0.0000e+00 - val_loss: -0.5696
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.1667 - loss: -0.1547 - val_accuracy: 0.0000e+00 - val_loss: -1.0102
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.1667 - loss: -0.5927 - val_accuracy: 0.0000e+00 - val_loss: -1.4269
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.1667 - loss: -1.0017 - val_accuracy: 0.0000e+00 - val_loss: -1.8197
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.1667 - loss: -1.3869 - val_accuracy: 0.0000e+00 - val_loss: -2.1845
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.1667 - loss: -1.7515 - val_accuracy: 0.0000e+00 - val_loss: -2.5451
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -2.1039 - val_accuracy: 0.0000e+00 - val_loss: -2.8896
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.1667 - loss: -2.4440 - val_accuracy: 0.0000e+00 - val_loss: -3.2212
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.1667 - loss: -2.7753 - val_accuracy: 0.0000e+00 - val_loss: -3.5472
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -3.0957 - val_accuracy: 0.0000e+00 - val_loss: -3.8643
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.1667 - loss: -3.4124 - val_accuracy: 0.0000e+00 - val_loss: -4.1761
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -3.7230 - val_accuracy: 0.0000e+00 - val_loss: -4.4872
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: -4.0333 - val_accuracy: 0.0000e+00 - val_loss: -4.7961
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -4.3427 - val_accuracy: 0.0000e+00 - val_loss: -5.1153
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.1667 - loss: -4.6516 - val_accuracy: 0.0000e+00 - val_loss: -5.4433
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.1667 - loss: -4.9613 - val_accuracy: 0.0000e+00 - val_loss: -5.7713
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.1667 - loss: -5.2708 - val_accuracy: 0.0000e+00 - val_loss: -6.1010
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.1667 - loss: -5.5776 - val_accuracy: 0.0000e+00 - val_loss: -6.4323
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -5.8833 - val_accuracy: 0.0000e+00 - val_loss: -6.7661
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.1667 - loss: -6.1895 - val_accuracy: 0.0000e+00 - val_loss: -7.0989
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.1667 - loss: -6.4972 - val_accuracy: 0.0000e+00 - val_loss: -7.4332
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.1667 - loss: -6.8065 - val_accuracy: 0.0000e+00 - val_loss: -7.7723
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.1667 - loss: -7.1163 - val_accuracy: 0.0000e+00 - val_loss: -8.1147
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.1667 - loss: -7.4281 - val_accuracy: 0.0000e+00 - val_loss: -8.4655
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.1667 - loss: -7.7440 - val_accuracy: 0.0000e+00 - val_loss: -8.8246
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.1667 - loss: -8.0645 - val_accuracy: 0.0000e+00 - val_loss: -9.1887
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: -8.3867 - val_accuracy: 0.0000e+00 - val_loss: -9.5567
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.1667 - loss: -8.7126 - val_accuracy: 0.0000e+00 - val_loss: -9.9289
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.1667 - loss: -9.0391 - val_accuracy: 0.0000e+00 - val_loss: -10.3042
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -9.3668 - val_accuracy: 0.0000e+00 - val_loss: -10.6801
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -9.6957 - val_accuracy: 0.0000e+00 - val_loss: -11.0570
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.1667 - loss: -10.0251 - val_accuracy: 0.0000e+00 - val_loss: -11.4334
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -10.3555 - val_accuracy: 0.0000e+00 - val_loss: -11.8100
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.1667 - loss: -10.6863 - val_accuracy: 0.0000e+00 - val_loss: -12.1875
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.1667 - loss: -11.0180 - val_accuracy: 0.0000e+00 - val_loss: -12.5670
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.1667 - loss: -11.3500 - val_accuracy: 0.0000e+00 - val_loss: -12.9517
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.1667 - loss: -11.6819 - val_accuracy: 0.0000e+00 - val_loss: -13.3402
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.1667 - loss: -12.0144 - val_accuracy: 0.0000e+00 - val_loss: -13.7297
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.1667 - loss: -12.3475 - val_accuracy: 0.0000e+00 - val_loss: -14.1188
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.1667 - loss: -12.6809 - val_accuracy: 0.0000e+00 - val_loss: -14.5089
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.1667 - loss: -13.0151 - val_accuracy: 0.0000e+00 - val_loss: -14.8999
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.1667 - loss: -13.3501 - val_accuracy: 0.0000e+00 - val_loss: -15.2917
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.1667 - loss: -13.6863 - val_accuracy: 0.0000e+00 - val_loss: -15.6845
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.1667 - loss: -14.0228 - val_accuracy: 0.0000e+00 - val_loss: -16.0784
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.1667 - loss: -14.3589 - val_accuracy: 0.0000e+00 - val_loss: -16.4733
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.1667 - loss: -14.6963 - val_accuracy: 0.0000e+00 - val_loss: -16.8677
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.1667 - loss: -15.0346 - val_accuracy: 0.0000e+00 - val_loss: -17.2626
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.0000e+00 - loss: -17.2626
# Validation Accuracy: 0.00%

# %% [markdown]
# ## Preparing Data Generators

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Define the path to your dataset
dataset_path = 'D:\Intel Unnati\Intel-Unnati-Project\Detection'  # Replace with your actual dataset path

# Load the MobileNetV2 model, pre-trained on ImageNet
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
base_model.trainable = False

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)  # Binary classification: pixelated vs non-pixelated

model = Model(inputs=base_model.input, outputs=outputs)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# Prepare data generators
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)
validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\I'
# <>:10: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21492\3178842617.py:10: SyntaxWarning: invalid escape sequence '\I'
#   dataset_path = 'D:\Intel Unnati\Intel-Unnati-Project\Detection'  # Replace with your actual dataset path
# Found 12 images belonging to 3 classes.
# Found 2 images belonging to 3 classes.

# %% [markdown]
# ## Training the Model

# %%
# Train the model
history = model.fit(train_generator, 
                    validation_data=validation_generator, 
                    epochs=50,  # Increase if validation performance improves
                    callbacks=[early_stopping])

# Save the model after training
model.save('pixel_detection_model.h5')

# Evaluate the model
loss, accuracy = model.evaluate(validation_generator)
print(f'Validation Accuracy: {accuracy * 100:.2f}%')

# Plot training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.1667 - loss: -0.5340 - val_accuracy: 0.0000e+00 - val_loss: -0.6528
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.1667 - loss: -0.9020 - val_accuracy: 0.0000e+00 - val_loss: -1.0841
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.1667 - loss: -1.2508 - val_accuracy: 0.0000e+00 - val_loss: -1.4934
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.1667 - loss: -1.5839 - val_accuracy: 0.0000e+00 - val_loss: -1.8925
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.1667 - loss: -1.8997 - val_accuracy: 0.0000e+00 - val_loss: -2.2806
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.1667 - loss: -2.2037 - val_accuracy: 0.0000e+00 - val_loss: -2.6591
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.1667 - loss: -2.5000 - val_accuracy: 0.0000e+00 - val_loss: -3.0252
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.1667 - loss: -2.7911 - val_accuracy: 0.0000e+00 - val_loss: -3.3797
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -3.0768 - val_accuracy: 0.0000e+00 - val_loss: -3.7305
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.1667 - loss: -3.3634 - val_accuracy: 0.0000e+00 - val_loss: -4.0800
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.1667 - loss: -3.6512 - val_accuracy: 0.0000e+00 - val_loss: -4.4294
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1667 - loss: -3.9364 - val_accuracy: 0.0000e+00 - val_loss: -4.7798
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -4.2201 - val_accuracy: 0.0000e+00 - val_loss: -5.1379
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: -4.5016 - val_accuracy: 0.0000e+00 - val_loss: -5.4966
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.1667 - loss: -4.7840 - val_accuracy: 0.0000e+00 - val_loss: -5.8501
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.1667 - loss: -5.0691 - val_accuracy: 0.0000e+00 - val_loss: -6.2117
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.1667 - loss: -5.3567 - val_accuracy: 0.0000e+00 - val_loss: -6.5771
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -5.6468 - val_accuracy: 0.0000e+00 - val_loss: -6.9465
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.1667 - loss: -5.9416 - val_accuracy: 0.0000e+00 - val_loss: -7.3172
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.1667 - loss: -6.2379 - val_accuracy: 0.0000e+00 - val_loss: -7.6954
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.1667 - loss: -6.5365 - val_accuracy: 0.0000e+00 - val_loss: -8.0870
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.1667 - loss: -6.8389 - val_accuracy: 0.0000e+00 - val_loss: -8.4797
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.1667 - loss: -7.1456 - val_accuracy: 0.0000e+00 - val_loss: -8.8726
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: -7.4572 - val_accuracy: 0.0000e+00 - val_loss: -9.2635
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.1667 - loss: -7.7721 - val_accuracy: 0.0000e+00 - val_loss: -9.6526
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.1667 - loss: -8.0889 - val_accuracy: 0.0000e+00 - val_loss: -10.0388
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.1667 - loss: -8.4075 - val_accuracy: 0.0000e+00 - val_loss: -10.4243
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.1667 - loss: -8.7320 - val_accuracy: 0.0000e+00 - val_loss: -10.8112
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.1667 - loss: -9.0590 - val_accuracy: 0.0000e+00 - val_loss: -11.1996
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.1667 - loss: -9.3892 - val_accuracy: 0.0000e+00 - val_loss: -11.5880
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.1667 - loss: -9.7213 - val_accuracy: 0.0000e+00 - val_loss: -11.9795
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1667 - loss: -10.0561 - val_accuracy: 0.0000e+00 - val_loss: -12.3805
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.1667 - loss: -10.3941 - val_accuracy: 0.0000e+00 - val_loss: -12.7896
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: -10.7363 - val_accuracy: 0.0000e+00 - val_loss: -13.2002
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: -11.0818 - val_accuracy: 0.0000e+00 - val_loss: -13.6118
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.1667 - loss: -11.4304 - val_accuracy: 0.0000e+00 - val_loss: -14.0254
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.1667 - loss: -11.7827 - val_accuracy: 0.0000e+00 - val_loss: -14.4400
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.1667 - loss: -12.1371 - val_accuracy: 0.0000e+00 - val_loss: -14.8546
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1667 - loss: -12.4941 - val_accuracy: 0.0000e+00 - val_loss: -15.2706
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.1667 - loss: -12.8530 - val_accuracy: 0.0000e+00 - val_loss: -15.6879
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.1667 - loss: -13.2141 - val_accuracy: 0.0000e+00 - val_loss: -16.1094
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.1667 - loss: -13.5767 - val_accuracy: 0.0000e+00 - val_loss: -16.5355
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: -13.9406 - val_accuracy: 0.0000e+00 - val_loss: -16.9663
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.1667 - loss: -14.3062 - val_accuracy: 0.0000e+00 - val_loss: -17.3984
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.1667 - loss: -14.6738 - val_accuracy: 0.0000e+00 - val_loss: -17.8316
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.1667 - loss: -15.0446 - val_accuracy: 0.0000e+00 - val_loss: -18.2674
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.1667 - loss: -15.4171 - val_accuracy: 0.0000e+00 - val_loss: -18.7054
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.1667 - loss: -15.7909 - val_accuracy: 0.0000e+00 - val_loss: -19.1447
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.1667 - loss: -16.1654 - val_accuracy: 0.0000e+00 - val_loss: -19.5853
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1667 - loss: -16.5414 - val_accuracy: 0.0000e+00 - val_loss: -20.0271
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0000e+00 - loss: -20.0271
# Validation Accuracy: 0.00%

# %% [markdown]
# ## Load the Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# Load the saved model
loaded_model = load_model('../saved_model/pixel_detection_model.h5')

# Compile the model (assuming 'adam' optimizer and 'binary_crossentropy' loss)
loaded_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 5
#       2 from tensorflow.keras.models import load_model
#       4 # Load the saved model
# ----> 5 loaded_model = load_model('../saved_model/pixel_detection_model.h5')
#       7 # Compile the model (assuming 'adam' optimizer and 'binary_crossentropy' loss)
#       8 loaded_model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
#
# File c:\Python312\Lib\site-packages\keras\src\saving\saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     182     return saving_lib.load_model(
#     183         filepath,
#     184         custom_objects=custom_objects,
#     185         compile=compile,
#     186         safe_mode=safe_mode,
#     187     )
#     188 if str(filepath).endswith((".h5", ".hdf5")):
# --> 189     return legacy_h5_format.load_model_from_hdf5(
#     190         filepath, custom_objects=custom_objects, compile=compile
#     191     )
#     192 elif str(filepath).endswith(".keras"):
#     193     raise ValueError(
#     194         f"File not found: filepath={filepath}. "
#     195         "Please ensure the file is an accessible `.keras` "
#     196         "zip file."
#     197     )
#
# File c:\Python312\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Python312\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File c:\Python312\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# OSError: Unable to synchronously open file (file signature not found)

# %% [markdown]
# ## Validation

# %%
# Evaluate the model
loss, accuracy = loaded_model.evaluate(validation_generator)
print(f'Validation Accuracy: {accuracy * 100:.2f}%')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 544ms/step - accuracy: 0.9786 - loss: 0.0373
# Validation Accuracy: 98.25%

# %% [markdown]
# ## F1 Score

# %% [markdown]
# > Done on 1200 images of caltech 256 image dataset (600 images in both classes)

# %%
import numpy as np
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define the path to your saved model
model_path = 'saved_model\\pixel_detection_model.h5'

# Load the saved model
loaded_model = load_model(model_path)

# Define a function to load and crop images to 224x224
def load_and_crop_image(img_path):
    img = image.load_img(img_path)
    width, height = img.size
    left = (width - 224) // 2
    top = (height - 224) // 2
    right = left + 224
    bottom = top + 224
    img = img.crop((left, top, right, bottom))
    img = img.convert('RGB')  # Ensure the image is in RGB mode
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize pixel values
    return img

# Validation on 700 images of caltech 256 image dataset
dataset_path = 'C:\\Users\\admin\\Desktop\\dataset_new'  # Replace with your actual dataset path

# Prepare a validation data generator to get file paths and true labels
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',  # Assuming binary classification (pixelated vs non-pixelated)
    shuffle=False  # Important: Do not shuffle for correct evaluation
)

# Manually load and crop images
all_images = []
true_labels = []
for i in range(len(validation_generator.filenames)):
    img_path = os.path.join(dataset_path, validation_generator.filenames[i])
    img = load_and_crop_image(img_path)
    all_images.append(img)
    true_labels.append(validation_generator.classes[i])

all_images = np.vstack(all_images)
true_labels = np.array(true_labels)

# Make predictions
predictions = loaded_model.predict(all_images)

# Convert probabilities to class labels (0 or 1)
predicted_labels = (predictions > 0.5).astype(int)

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels)

print(f'F1 Score: {f1:.2f}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 1200 images belonging to 2 classes.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 22s 534ms/step
# F1 Score: 0.96

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

print("Confusion Matrix:")
print(cm)

# Print precision, recall, and F1 score
from sklearn.metrics import classification_report
report = classification_report(true_labels, predicted_labels, target_names=['Non-Pixelated', 'Pixelated'])

print("Classification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[599   1]
#  [ 49 551]]
# Classification Report:
#                precision    recall  f1-score   support
#
# Non-Pixelated       0.92      1.00      0.96       600
#     Pixelated       1.00      0.92      0.96       600
#
#      accuracy                           0.96      1200
#     macro avg       0.96      0.96      0.96      1200
#  weighted avg       0.96      0.96      0.96      1200

# %% [markdown]
# ## Sample output for images of size 224x224

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Path to the folder containing the images
folder_path = 'test_sample'  # Replace with your folder path

# Get list of all image files in the folder
image_files = sorted(os.listdir(folder_path))

# Load and preprocess images
images = []
for img_file in image_files:
    img_path = os.path.join(folder_path, img_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize pixel values
    images.append(img)

images = np.vstack(images)  # Stack images into a single batch

# Make predictions using the loaded model
predictions = loaded_model.predict(images)

# Convert predictions to class labels in words
predicted_labels = ['Pixelated' if pred > 0.5 else 'Non-Pixelated' for pred in predictions]

# Display images with predictions
plt.figure(figsize=(15, 8))
num_images = len(image_files)  # Total number of images in the folder
rows = 2  # Number of rows for subplot grid
cols = (num_images + rows - 1) // rows  # Calculate number of columns needed

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(images[i])
    plt.title(f'Prediction: {predicted_labels[i]}')  # Display prediction
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step

# %% [markdown]
# ## Testing

# %% [markdown]
# <blockquote> Specify the folder path containing test images (any dimensions) </blockquote>

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Path to the folder containing the images
folder_path = 'C:\\Users\\admin\\Desktop\\pixelated'  # Replace with your folder path

image_files = sorted(os.listdir(folder_path))

# load and crop images to 224x224 
def load_and_crop_image(img_path):
    img = image.load_img(img_path)
    width, height = img.size
    left = (width - 224) // 2
    top = (height - 224) // 2
    right = left + 224
    bottom = top + 224
    img = img.crop((left, top, right, bottom))
    img = img.convert('RGB')  # Ensure the image is in RGB mode
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize pixel values
    return img # Return the cropped image

# Load and preprocess images
images = []
original_images = []

for img_file in image_files:
    img_path = os.path.join(folder_path, img_file)
    img = load_and_crop_image(img_path)
    original_img = image.load_img(img_path, target_size=(224, 224))  # Load original image
    original_images.append(original_img)
    images.append(img)

images = np.vstack(images)  # Stack images into a single batch

# Make predictions using the loaded model (Execute the "Load the Model" cell before this)
start_time = time.time()
predictions = loaded_model.predict(images)
end_time = time.time()

# Calculate FPS
num_images = len(image_files)
elapsed_time = end_time - start_time
fps = num_images / elapsed_time

print(f"Number of images: {num_images}")
print(f"Elapsed time: {elapsed_time:.2f} seconds")
print(f"FPS: {fps:.2f}")

# Convert predictions to class labels in words
predicted_labels = ['Pixelated' if pred > 0.5 else 'Non-Pixelated' for pred in predictions]

# Calculate number of rows and columns for subplot grid
num_rows = (num_images + 2) // 3  # Display 3 images per row
num_cols = 3

# Adjust figure size based on number of images
plt.figure(figsize=(18, 6 * num_rows))

# Plot images with predictions
for i in range(num_images):
    plt.subplot(num_rows, num_cols, i + 1)
    
    # Plot original image
    plt.imshow(original_images[i])
    
    # Display prediction
    plt.title(f'Prediction: {predicted_labels[i]}', fontsize=12)
    plt.axis('off')

plt.tight_layout(pad=3.0)  # spacing between subplots
plt.show()

# %% [markdown]
# ## FPS Calculation

# %%
import os
import time
import numpy as np
from tensorflow.keras.preprocessing import image

# Path to the folder containing the images
folder_path = '.../test_sample'  # Replace with your folder path

image_files = sorted(os.listdir(folder_path))

# load and crop images to 224x224 
def load_and_crop_image(img_path):
    img = image.load_img(img_path)
    width, height = img.size
    left = (width - 224) // 2
    top = (height - 224) // 2
    right = left + 224
    bottom = top + 224
    img = img.crop((left, top, right, bottom))
    img = img.convert('RGB')  # Ensure the image is in RGB mode
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize pixel values
    return img # Return the cropped image

# Load and preprocess images
images = []
for img_file in image_files:
    img_path = os.path.join(folder_path, img_file)
    img = load_and_crop_image(img_path)
    images.append(img)

images = np.vstack(images)  # Stack images into a single batch

# Make predictions using the loaded model (Execute the "Load the Model" cell before this)
start_time = time.time()
predictions = loaded_model.predict(images)
end_time = time.time()

# Calculate FPS
num_images = len(image_files)
elapsed_time = end_time - start_time
fps = num_images / elapsed_time

print(f"Number of images: {num_images}")
print(f"Elapsed time: {elapsed_time:.2f} seconds")
print(f"FPS: {fps:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 634ms/step
# Number of images: 400
# Elapsed time: 9.76 seconds
# FPS: 41.00
